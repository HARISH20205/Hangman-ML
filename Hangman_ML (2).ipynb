# %%
import string
import random
import numpy as np
import pandas as np
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/drive')

# Load the word list from the file
try:
    with open(r'/content/drive/MyDrive/Hangman/Hangman Word List.txt') as f:
        word_list = f.read().splitlines()
except FileNotFoundError:
    print("Word list file not found. Please check the file path.")
    exit(1)

if not word_list:
    print("Word list is empty. Cannot proceed with the game.")
    exit(1)

# Split the word list into training and testing sets
train_words, test_words = train_test_split(word_list, test_size=0.2, random_state=42)

# Function of ngrams
def ngrams(text, n):
    """
    Generate n-grams from the given text.

    Args:
        text (str): The input text.
        n (int): The order of the n-grams.

    Returns:
        list: A list of n-grams.
    """
    ngrams = []
    for i in range(len(text) - n + 1):
        ngrams.append(text[i:i+n])
    return ngrams

# Function to train the n-gram model
def train_ngram_model(word_list, n=3):
    """
    Train an n-gram model on the given word list.

    Args:
        word_list (list): A list of words to train the model on.
        n (int): The order of the n-gram model (default: 3).

    Returns:
        dict: A dictionary representing the n-gram model.
    """
    model = {}
    for word in word_list:
        word = '<' + word + '>'  # Add start and end tokens
        grams = ngrams(word, n)
        for gram in grams:
            key = gram[:-1]
            next_char = gram[-1]
            if key in model:
                model[key][next_char] += 1
            else:
                model[key] = Counter({next_char: 1})
    return model

# Function to generate the machine's guess using the n-gram model, word similarity, and most used letters
def generate_guess(ngram_model, word_state, used_letters, same_length_words, most_used_letters):
    """
    Generate the machine's guess based on various strategies.

    Args:
        ngram_model (dict): The n-gram model.
        word_state (list): The current state of the word.
        used_letters (set): The set of letters already used.
        same_length_words (list): A list of words with the same length as the target word.
        most_used_letters (list): A list of the most commonly used letters.

    Returns:
        str: The machine's guess.
    """
    # Prioritize guessing vowels in the initial guesses
    vowels = set('aeiou')
    if len(used_letters) < 3:
        for vowel in vowels:
            if vowel not in used_letters:
                return vowel

    # Use the n-gram model
    context = '<' + ''.join(word_state)
    if len(context) >= 3:
        context = context[-3:]
        if context in ngram_model:
            next_char_counter = ngram_model[context]
            for char, _ in next_char_counter.most_common():
                if char not in used_letters:
                    return char

    # Use word similarity with same-length words
    vectorizer = CountVectorizer(analyzer='char', ngram_range=(1, 3))
    word_vectors = vectorizer.fit_transform(same_length_words)
    query_vector = vectorizer.transform([''.join(word_state)])
    similarities = cosine_similarity(query_vector, word_vectors)[0]
    sorted_indices = similarities.argsort()[::-1]

    for idx in sorted_indices:
        word = same_length_words[idx]
        for char in word:
            if char not in used_letters and char not in word_state:
                return char

    # Prioritize guessing the most used letters
    for char in most_used_letters:
        if char not in used_letters and char not in word_state:
            return char

    # If all else fails, choose a random unused letter
    return random.choice([char for char in string.ascii_lowercase if char not in used_letters])

# Function to play the game
def play_game(word_list, ngram_model, most_used_letters, num_guesses=10):
    """
    Play a single game of Hangman.

    Args:
        word_list (list): A list of words to choose the target word from.
        ngram_model (dict): The n-gram model.
        most_used_letters (list): A list of the most commonly used letters.
        num_guesses (int): The number of guesses allowed (default: 10).

    Returns:
        bool: True if the machine guessed the word correctly, False otherwise.
    """
    word = random.choice(word_list)
    word_length = len(word)
    same_length_words = [w for w in word_list if len(w) == word_length]
    used_letters = set()
    remaining_guesses = num_guesses
    word_state = ['_'] * word_length

    while remaining_guesses > 0:
        guess = generate_guess(ngram_model, word_state, used_letters, same_length_words, most_used_letters)
        used_letters.add(guess)

        # Update the word state based on the guess
        for i, char in enumerate(word):
            if char == guess:
                word_state[i] = char

        if guess not in word:
            remaining_guesses -= 1
            print(f"Oops! The letter '{guess}' is not in the word. Remaining guesses: {remaining_guesses}")
        else:
            print(f"Good guess! The word is now: {''.join(word_state)}")

        if '_' not in word_state:
            print(f"Congratulations! The machine guessed the word: {''.join(word_state)}")
            return True

    print(f"Sorry, the machine ran out of guesses. The word was: {word}")
    return False

def main():
    # Train the n-gram model on the training set
    ngram_model = train_ngram_model(train_words)

    # Get the most used letters from the training set
    letter_counts = Counter(''.join(train_words))
    most_used_letters = [char for char, count in letter_counts.most_common()]

    # Play the game and evaluate the accuracy
    num_correct = 0
    num_games = 100
    num_guesses = 10  # Number of guesses allowed

    for _ in range(num_games):
        if play_game(test_words, ngram_model, most_used_letters, num_guesses):
            num_correct += 1

    accuracy = num_correct / num_games
    print(f"Accuracy: {accuracy:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Good guess! The word is now: ___e____
# Good guess! The word is now: ___e__a_
# Good guess! The word is now: _u_e__a_
# Oops! The letter 'n' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _u_e__as
# Oops! The letter 'g' is not in the word. Remaining guesses: 8
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Oops! The letter 'd' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _uce__as
# Good guess! The word is now: buce__as
# Good guess! The word is now: bucellas
# Congratulations! The machine guessed the word: bucellas
# Good guess! The word is now: ___e_________e_e___
# Good guess! The word is now: ___e___a_____e_e___
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ___e___a_c___e_e___
# Oops! The letter 'o' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ___en__anc___e_en__
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Oops! The letter 'z' is not in the word. Remaining guesses: 6
# Oops! The letter 'p' is not in the word. Remaining guesses: 5
# Good guess! The word is now: ___en__anch__e_en__
# Good guess! The word is now: ___en__anch__e_ent_
# Good guess! The word is now: d__en__anch__e_ent_
# Good guess! The word is now: di_en__anchi_e_ent_
# Good guess! The word is now: disen__anchise_ents
# Good guess! The word is now: disenf_anchise_ents
# Good guess! The word is now: disenfranchise_ents
# Good guess! The word is now: disenfranchisements
# Congratulations! The machine guessed the word: disenfranchisements
# Good guess! The word is now: __________e_
# Good guess! The word is now: __a_______e_
# Good guess! The word is now: _ua_____u_e_
# Good guess! The word is now: qua_____u_e_
# Good guess! The word is now: qua_____uce_
# Good guess! The word is now: qua_ii__uce_
# Good guess! The word is now: quasii__uce_
# Good guess! The word is now: quasiin_uce_
# Good guess! The word is now: quasiinduced
# Congratulations! The machine guessed the word: quasiinduced
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Oops! The letter 'a' is not in the word. Remaining guesses: 8
# Oops! The letter 'u' is not in the word. Remaining guesses: 7
# Oops! The letter 'c' is not in the word. Remaining guesses: 6
# Oops! The letter 'f' is not in the word. Remaining guesses: 5
# Oops! The letter 'i' is not in the word. Remaining guesses: 4
# Oops! The letter 't' is not in the word. Remaining guesses: 3
# Oops! The letter 'r' is not in the word. Remaining guesses: 2
# Oops! The letter 's' is not in the word. Remaining guesses: 1
# Good guess! The word is now: __o
# Good guess! The word is now: _bo
# Oops! The letter 'q' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: hbo
# Good guess! The word is now: e___
# Good guess! The word is now: e__a
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'w' is not in the word. Remaining guesses: 8
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 'r' is not in the word. Remaining guesses: 5
# Good guess! The word is now: el_a
# Good guess! The word is now: elva
# Congratulations! The machine guessed the word: elva
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Oops! The letter 'a' is not in the word. Remaining guesses: 8
# Oops! The letter 'u' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ______t___
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Oops! The letter 'b' is not in the word. Remaining guesses: 5
# Good guess! The word is now: ____i_ti__
# Oops! The letter 'm' is not in the word. Remaining guesses: 4
# Good guess! The word is now: ____i_ti_g
# Good guess! The word is now: n_n_i_ting
# Good guess! The word is now: non_i_ting
# Good guess! The word is now: nonli_ting
# Good guess! The word is now: nonlisting
# Congratulations! The machine guessed the word: nonlisting
# Good guess! The word is now: _e_____e_
# Good guess! The word is now: _e_a_a_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _e_a_a_ed
# Oops! The letter 'p' is not in the word. Remaining guesses: 8
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Good guess! The word is now: re_a_a_ed
# Good guess! The word is now: re_a_ated
# Good guess! The word is now: reva_ated
# Good guess! The word is now: revacated
# Congratulations! The machine guessed the word: revacated
# Good guess! The word is now: _e_______
# Good guess! The word is now: _e____a__
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'd' is not in the word. Remaining guesses: 8
# Oops! The letter 'o' is not in the word. Remaining guesses: 7
# Oops! The letter 'x' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _e___ca__
# Good guess! The word is now: _er__ca__
# Good guess! The word is now: _ert_ca__
# Good guess! The word is now: _ert_cal_
# Good guess! The word is now: vert_cal_
# Oops! The letter 'n' is not in the word. Remaining guesses: 5
# Good guess! The word is now: vertical_
# Good guess! The word is now: verticals
# Congratulations! The machine guessed the word: verticals
# Good guess! The word is now: ____e_e______e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: __s_e_e______e_
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 'x' is not in the word. Remaining guesses: 5
# Oops! The letter 'p' is not in the word. Remaining guesses: 4
# Good guess! The word is now: __s_ere______e_
# Good guess! The word is now: __stere_t____e_
# Good guess! The word is now: __stere_to___e_
# Good guess! The word is now: __sterecto___e_
# Good guess! The word is now: h_sterecto___e_
# Good guess! The word is now: hysterecto___e_
# Good guess! The word is now: hysterectom__e_
# Good guess! The word is now: hysterectomi_e_
# Good guess! The word is now: hysterectomize_
# Good guess! The word is now: hysterectomized
# Congratulations! The machine guessed the word: hysterectomized
# Good guess! The word is now: ________e
# Good guess! The word is now: ___a____e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'd' is not in the word. Remaining guesses: 8
# Oops! The letter 'o' is not in the word. Remaining guesses: 7
# Oops! The letter 'x' is not in the word. Remaining guesses: 6
# Good guess! The word is now: c_ca___ce
# Oops! The letter 's' is not in the word. Remaining guesses: 5
# Oops! The letter 'n' is not in the word. Remaining guesses: 4
# Good guess! The word is now: cica__ice
# Good guess! The word is now: cicat_ice
# Good guess! The word is now: cicatrice
# Congratulations! The machine guessed the word: cicatrice
# Good guess! The word is now: _______e_
# Good guess! The word is now: a____a_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'n' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ab___a_e_
# Good guess! The word is now: ab___ate_
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Oops! The letter 'c' is not in the word. Remaining guesses: 5
# Good guess! The word is now: abr__ate_
# Good guess! The word is now: abro_ate_
# Good guess! The word is now: abrogate_
# Good guess! The word is now: abrogated
# Congratulations! The machine guessed the word: abrogated
# Good guess! The word is now: _____e__
# Good guess! The word is now: __a__e__
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'f' is not in the word. Remaining guesses: 8
# Good guess! The word is now: __a_be__
# Good guess! The word is now: __adbed_
# Good guess! The word is now: r_adbed_
# Good guess! The word is now: roadbed_
# Good guess! The word is now: roadbeds
# Congratulations! The machine guessed the word: roadbeds
# Good guess! The word is now: ___e__e_
# Good guess! The word is now: ___ea_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 's' is not in the word. Remaining guesses: 8
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ___ea_ed
# Good guess! The word is now: w__eawed
# Good guess! The word is now: wi_eawed
# Good guess! The word is now: wifeawed
# Congratulations! The machine guessed the word: wifeawed
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Oops! The letter 'a' is not in the word. Remaining guesses: 8
# Oops! The letter 'u' is not in the word. Remaining guesses: 7
# Oops! The letter 'b' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _i____
# Oops! The letter 'r' is not in the word. Remaining guesses: 5
# Oops! The letter 't' is not in the word. Remaining guesses: 4
# Oops! The letter 'c' is not in the word. Remaining guesses: 3
# Oops! The letter 'm' is not in the word. Remaining guesses: 2
# Oops! The letter 'd' is not in the word. Remaining guesses: 1
# Oops! The letter 'x' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: pinyon
# Good guess! The word is now: ________e
# Good guess! The word is now: _a______e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'd' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _a_o____e
# Oops! The letter 'x' is not in the word. Remaining guesses: 7
# Oops! The letter 'c' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _alo___le
# Good guess! The word is now: _alo__ile
# Good guess! The word is now: halo_hile
# Good guess! The word is now: halophile
# Congratulations! The machine guessed the word: halophile
# Good guess! The word is now: _______e__
# Good guess! The word is now: _______e_a
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 's' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _______eca
# Oops! The letter 'r' is not in the word. Remaining guesses: 5
# Good guess! The word is now: ___i___eca
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Good guess! The word is now: ___i__heca
# Good guess! The word is now: _o_io_heca
# Good guess! The word is now: go_io_heca
# Good guess! The word is now: gonio_heca
# Good guess! The word is now: goniotheca
# Congratulations! The machine guessed the word: goniotheca
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____a_
# Good guess! The word is now: _u__a_
# Oops! The letter 'v' is not in the word. Remaining guesses: 8
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Oops! The letter 'p' is not in the word. Remaining guesses: 6
# Oops! The letter 'k' is not in the word. Remaining guesses: 5
# Oops! The letter 'h' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _ugga_
# Good guess! The word is now: mugga_
# Good guess! The word is now: muggar
# Congratulations! The machine guessed the word: muggar
# Good guess! The word is now: _________e
# Good guess! The word is now: __a___a__e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 's' is not in the word. Remaining guesses: 8
# Good guess! The word is now: b_a___a__e
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Oops! The letter 'c' is not in the word. Remaining guesses: 6
# Oops! The letter 'n' is not in the word. Remaining guesses: 5
# Good guess! The word is now: b_a___ai_e
# Good guess! The word is now: bra___ai_e
# Oops! The letter 'f' is not in the word. Remaining guesses: 4
# Good guess! The word is now: brat__aite
# Good guess! The word is now: brath_aite
# Good guess! The word is now: brathwaite
# Congratulations! The machine guessed the word: brathwaite
# Good guess! The word is now: ___e___e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ___el__e_
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ___el_ve_
# Good guess! The word is now: ___el_ved
# Oops! The letter 'o' is not in the word. Remaining guesses: 5
# Good guess! The word is now: n_nel_ved
# Good guess! The word is now: ninelived
# Congratulations! The machine guessed the word: ninelived
# Good guess! The word is now: _________e_
# Good guess! The word is now: a________e_
# Good guess! The word is now: a__u_____e_
# Good guess! The word is now: a__u_____es
# Good guess! The word is now: a__u_t___es
# Oops! The letter 'h' is not in the word. Remaining guesses: 9
# Good guess! The word is now: a_ru_t___es
# Oops! The letter 'c' is not in the word. Remaining guesses: 8
# Good guess! The word is now: a_ru_ti__es
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Good guess! The word is now: a_rupti__es
# Good guess! The word is now: abrupti__es
# Good guess! The word is now: abruptio_es
# Good guess! The word is now: abruptiones
# Congratulations! The machine guessed the word: abruptiones
# Good guess! The word is now: _____e____e
# Good guess! The word is now: ____ae___ae
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 's' is not in the word. Remaining guesses: 8
# Good guess! The word is now: c___ae___ae
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Good guess! The word is now: c___aer__ae
# Good guess! The word is now: ch__aer__ae
# Good guess! The word is now: chi_aeri_ae
# Good guess! The word is now: chimaeri_ae
# Good guess! The word is now: chimaeridae
# Congratulations! The machine guessed the word: chimaeridae
# Good guess! The word is now: ________e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ______u_e_
# Oops! The letter 'n' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ____s_u_es
# Oops! The letter 'j' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ____stu_es
# Good guess! The word is now: __p_stu_es
# Good guess! The word is now: i_p_stu_es
# Oops! The letter 'd' is not in the word. Remaining guesses: 6
# Good guess! The word is now: imp_stu_es
# Good guess! The word is now: impostu_es
# Good guess! The word is now: impostures
# Congratulations! The machine guessed the word: impostures
# Good guess! The word is now: _e___e____
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _ett_e____
# Good guess! The word is now: _ett_e___n
# Good guess! The word is now: _ettle___n
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Oops! The letter 'x' is not in the word. Remaining guesses: 5
# Good guess! The word is now: settle___n
# Good guess! The word is now: settled__n
# Good guess! The word is now: settledo_n
# Good guess! The word is now: settledown
# Congratulations! The machine guessed the word: settledown
# Good guess! The word is now: ______e
# Good guess! The word is now: __a___e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: __an__e
# Oops! The letter 'c' is not in the word. Remaining guesses: 8
# Good guess! The word is now: __and_e
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Oops! The letter 's' is not in the word. Remaining guesses: 4
# Oops! The letter 'm' is not in the word. Remaining guesses: 3
# Oops! The letter 'v' is not in the word. Remaining guesses: 2
# Oops! The letter 'y' is not in the word. Remaining guesses: 1
# Good guess! The word is now: b_and_e
# Good guess! The word is now: b_andie
# Good guess! The word is now: brandie
# Congratulations! The machine guessed the word: brandie
# Good guess! The word is now: _e__e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'p' is not in the word. Remaining guesses: 7
# Oops! The letter 'd' is not in the word. Remaining guesses: 6
# Oops! The letter 'j' is not in the word. Remaining guesses: 5
# Oops! The letter 't' is not in the word. Remaining guesses: 4
# Oops! The letter 'h' is not in the word. Remaining guesses: 3
# Oops! The letter 's' is not in the word. Remaining guesses: 2
# Oops! The letter 'r' is not in the word. Remaining guesses: 1
# Oops! The letter 'f' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: vennel
# Good guess! The word is now: _____e_______
# Good guess! The word is now: _____e_a_____
# Good guess! The word is now: __u__e_a__u__
# Good guess! The word is now: __u__era__u__
# Good guess! The word is now: __u_tera__u__
# Good guess! The word is now: _ou_tera__u__
# Oops! The letter 'l' is not in the word. Remaining guesses: 9
# Good guess! The word is now: cou_tera__u__
# Good guess! The word is now: countera__u__
# Oops! The letter 'g' is not in the word. Remaining guesses: 8
# Good guess! The word is now: countera__us_
# Good guess! The word is now: counteram_us_
# Good guess! The word is now: counterambus_
# Good guess! The word is now: counterambush
# Congratulations! The machine guessed the word: counterambush
# Good guess! The word is now: _e___
# Good guess! The word is now: _e__a
# Good guess! The word is now: _eu_a
# Good guess! The word is now: ceu_a
# Good guess! The word is now: ceuta
# Congratulations! The machine guessed the word: ceuta
# Good guess! The word is now: ________e_
# Good guess! The word is now: _a______e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: sa___s__es
# Oops! The letter 'b' is not in the word. Remaining guesses: 8
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Good guess! The word is now: sa__is_ies
# Good guess! The word is now: sac_is_ies
# Good guess! The word is now: sacris_ies
# Good guess! The word is now: sacristies
# Congratulations! The machine guessed the word: sacristies
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____a______
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: __t_a_____t
# Oops! The letter 'n' is not in the word. Remaining guesses: 7
# Oops! The letter 'y' is not in the word. Remaining guesses: 6
# Good guess! The word is now: __t_a____st
# Oops! The letter 'o' is not in the word. Remaining guesses: 5
# Oops! The letter 'm' is not in the word. Remaining guesses: 4
# Good guess! The word is now: __t_a_ll_st
# Oops! The letter 'c' is not in the word. Remaining guesses: 3
# Good guess! The word is now: _it_aillist
# Good guess! The word is now: vit_aillist
# Good guess! The word is now: vitraillist
# Congratulations! The machine guessed the word: vitraillist
# Good guess! The word is now: _e_e__e_e______
# Good guess! The word is now: _e_e__e_e___a__
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'f' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _ele__e_e___a__
# Oops! The letter 'w' is not in the word. Remaining guesses: 6
# Oops! The letter 'x' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _ele__e_e___ap_
# Good guess! The word is now: _ele__ere__rap_
# Good guess! The word is now: tele_tere__rap_
# Good guess! The word is now: telestere__rap_
# Good guess! The word is now: telestereo_rap_
# Good guess! The word is now: telestereograp_
# Good guess! The word is now: telestereograph
# Congratulations! The machine guessed the word: telestereograph
# Good guess! The word is now: e____e_e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Oops! The letter 'k' is not in the word. Remaining guesses: 5
# Oops! The letter 'n' is not in the word. Remaining guesses: 4
# Good guess! The word is now: e____e_ed
# Good guess! The word is now: e____ered
# Oops! The letter 't' is not in the word. Remaining guesses: 3
# Good guess! The word is now: e___wered
# Oops! The letter 'z' is not in the word. Remaining guesses: 2
# Good guess! The word is now: em__wered
# Oops! The letter 'p' is not in the word. Remaining guesses: 1
# Good guess! The word is now: em_owered
# Good guess! The word is now: embowered
# Congratulations! The machine guessed the word: embowered
# Good guess! The word is now: ______e__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ______es_
# Good guess! The word is now: t_____est
# Oops! The letter 'y' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ti___iest
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 'g' is not in the word. Remaining guesses: 5
# Oops! The letter 'r' is not in the word. Remaining guesses: 4
# Oops! The letter 'h' is not in the word. Remaining guesses: 3
# Good guess! The word is now: tin__iest
# Good guess! The word is now: tink_iest
# Good guess! The word is now: tinkliest
# Congratulations! The machine guessed the word: tinkliest
# Good guess! The word is now: ____ee__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'r' is not in the word. Remaining guesses: 7
# Oops! The letter 's' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ___teet_
# Good guess! The word is now: d__teet_
# Good guess! The word is now: do_teet_
# Good guess! The word is now: dogteet_
# Good guess! The word is now: dogteeth
# Congratulations! The machine guessed the word: dogteeth
# Good guess! The word is now: _e_________e____e__
# Good guess! The word is now: _e_______a_e____e__
# Good guess! The word is now: _e_______a_e_u__e__
# Oops! The letter 'c' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _e____o__a_eou__e__
# Good guess! The word is now: se__s_o__a_eous_ess
# Good guess! The word is now: sem_s_o__a_eous_ess
# Good guess! The word is now: semis_o__a_eous_ess
# Good guess! The word is now: semispo__a_eous_ess
# Good guess! The word is now: semispon_aneousness
# Good guess! The word is now: semispontaneousness
# Congratulations! The machine guessed the word: semispontaneousness
# Good guess! The word is now: _e_________
# Good guess! The word is now: _e____a____
# Good guess! The word is now: _e_u__a____
# Good guess! The word is now: se_u__a____
# Good guess! The word is now: se_u__at___
# Oops! The letter 'm' is not in the word. Remaining guesses: 9
# Good guess! The word is now: se_u__ati__
# Oops! The letter 'x' is not in the word. Remaining guesses: 8
# Oops! The letter 'p' is not in the word. Remaining guesses: 7
# Oops! The letter 'v' is not in the word. Remaining guesses: 6
# Oops! The letter 'q' is not in the word. Remaining guesses: 5
# Good guess! The word is now: secu__ati__
# Good guess! The word is now: secun_ati_n
# Good guess! The word is now: secundati_n
# Good guess! The word is now: secundation
# Congratulations! The machine guessed the word: secundation
# Good guess! The word is now: _e_________
# Good guess! The word is now: _e_a_a_____
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'p' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _e_a_al____
# Good guess! The word is now: _e_a_al_s_s
# Oops! The letter 'o' is not in the word. Remaining guesses: 7
# Oops! The letter 'c' is not in the word. Remaining guesses: 6
# Oops! The letter 'f' is not in the word. Remaining guesses: 5
# Oops! The letter 'r' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _ema_al_s_s
# Good guess! The word is now: hema_al_s_s
# Good guess! The word is now: hemanal_s_s
# Good guess! The word is now: hemanalys_s
# Good guess! The word is now: hemanalysis
# Congratulations! The machine guessed the word: hemanalysis
# Good guess! The word is now: ____e_____
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ____e___t_
# Oops! The letter 'n' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Good guess! The word is now: ___re__rt_
# Good guess! The word is now: _i_re__rt_
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _i_re_ort_
# Good guess! The word is now: mi_re_ort_
# Good guess! The word is now: misre_orts
# Good guess! The word is now: misreports
# Congratulations! The machine guessed the word: misreports
# Good guess! The word is now: _e_____
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _e___u_
# Oops! The letter 'n' is not in the word. Remaining guesses: 8
# Oops! The letter 'q' is not in the word. Remaining guesses: 7
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ded__u_
# Oops! The letter 'r' is not in the word. Remaining guesses: 5
# Oops! The letter 'c' is not in the word. Remaining guesses: 4
# Good guess! The word is now: dedi_u_
# Good guess! The word is now: dedimu_
# Good guess! The word is now: dedimus
# Congratulations! The machine guessed the word: dedimus
# Good guess! The word is now: _e______
# Good guess! The word is now: _e____a_
# Good guess! The word is now: _e__u_a_
# Good guess! The word is now: _e__u_an
# Oops! The letter 'd' is not in the word. Remaining guesses: 9
# Oops! The letter 'r' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Good guess! The word is now: te__u_an
# Oops! The letter 'i' is not in the word. Remaining guesses: 6
# Oops! The letter 'v' is not in the word. Remaining guesses: 5
# Oops! The letter 'l' is not in the word. Remaining guesses: 4
# Oops! The letter 'm' is not in the word. Remaining guesses: 3
# Oops! The letter 'x' is not in the word. Remaining guesses: 2
# Oops! The letter 'f' is not in the word. Remaining guesses: 1
# Oops! The letter 's' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: tezcucan
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _a____
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'k' is not in the word. Remaining guesses: 7
# Oops! The letter 'w' is not in the word. Remaining guesses: 6
# Oops! The letter 'c' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _an___
# Oops! The letter 'h' is not in the word. Remaining guesses: 4
# Oops! The letter 'd' is not in the word. Remaining guesses: 3
# Oops! The letter 'b' is not in the word. Remaining guesses: 2
# Oops! The letter 'l' is not in the word. Remaining guesses: 1
# Oops! The letter 'i' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: pantry
# Good guess! The word is now: _______e
# Good guess! The word is now: _a_____e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _a_f___e
# Oops! The letter 'b' is not in the word. Remaining guesses: 8
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Oops! The letter 'd' is not in the word. Remaining guesses: 6
# Oops! The letter 't' is not in the word. Remaining guesses: 5
# Oops! The letter 's' is not in the word. Remaining guesses: 4
# Oops! The letter 'n' is not in the word. Remaining guesses: 3
# Good guess! The word is now: _alf___e
# Good guess! The word is now: half___e
# Oops! The letter 'o' is not in the word. Remaining guesses: 2
# Good guess! The word is now: half__pe
# Good guess! The word is now: halfr_pe
# Good guess! The word is now: halfripe
# Congratulations! The machine guessed the word: halfripe
# Good guess! The word is now: ____e___
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'd' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ____ef__
# Oops! The letter 'n' is not in the word. Remaining guesses: 6
# Oops! The letter 't' is not in the word. Remaining guesses: 5
# Good guess! The word is now: __r_ef__
# Oops! The letter 'z' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _or_ef__
# Oops! The letter 'g' is not in the word. Remaining guesses: 3
# Oops! The letter 'm' is not in the word. Remaining guesses: 2
# Good guess! The word is now: _orsef__
# Good guess! The word is now: horsef__
# Good guess! The word is now: horsefl_
# Good guess! The word is now: horsefly
# Congratulations! The machine guessed the word: horsefly
# Good guess! The word is now: _e_____e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _e__u__e_
# Oops! The letter 'b' is not in the word. Remaining guesses: 8
# Oops! The letter 'z' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _e__usse_
# Good guess! The word is now: _e__ussed
# Good guess! The word is now: pe__ussed
# Good guess! The word is now: per_ussed
# Good guess! The word is now: percussed
# Congratulations! The machine guessed the word: percussed
# Good guess! The word is now: _____e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _y___e_
# Good guess! The word is now: _ys__es
# Oops! The letter 'd' is not in the word. Remaining guesses: 7
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Good guess! The word is now: lys__es
# Good guess! The word is now: lysi_es
# Good guess! The word is now: lysines
# Congratulations! The machine guessed the word: lysines
# Good guess! The word is now: ___e________
# Good guess! The word is now: ___e___a____
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'l' is not in the word. Remaining guesses: 8
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ___e___a__n_
# Good guess! The word is now: ___e___a__ng
# Good guess! The word is now: ___e_t_at_ng
# Good guess! The word is now: __ie_t_ating
# Good guess! The word is now: _rie_t_ating
# Good guess! The word is now: prie_t_ating
# Good guess! The word is now: priest_ating
# Good guess! The word is now: priesthating
# Congratulations! The machine guessed the word: priesthating
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ___a
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: b__a
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Oops! The letter 'y' is not in the word. Remaining guesses: 5
# Oops! The letter 'c' is not in the word. Remaining guesses: 4
# Oops! The letter 'r' is not in the word. Remaining guesses: 3
# Good guess! The word is now: bi_a
# Good guess! The word is now: bida
# Congratulations! The machine guessed the word: bida
# Good guess! The word is now: ____e_e
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'y' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ____ene
# Good guess! The word is now: ___gene
# Oops! The letter 's' is not in the word. Remaining guesses: 5
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Oops! The letter 'r' is not in the word. Remaining guesses: 3
# Oops! The letter 'i' is not in the word. Remaining guesses: 2
# Oops! The letter 'c' is not in the word. Remaining guesses: 1
# Good guess! The word is now: z__gene
# Good guess! The word is now: zoogene
# Congratulations! The machine guessed the word: zoogene
# Good guess! The word is now: ________e_
# Good guess! The word is now: _a____a_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 's' is not in the word. Remaining guesses: 8
# Oops! The letter 'b' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _a____ale_
# Good guess! The word is now: _a___gale_
# Oops! The letter 'o' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _ad__gale_
# Good guess! The word is now: _ad_igale_
# Good guess! The word is now: mad_igale_
# Good guess! The word is now: madrigaler
# Congratulations! The machine guessed the word: madrigaler
# Good guess! The word is now: _________e
# Good guess! The word is now: _a_______e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _as______e
# Oops! The letter 'b' is not in the word. Remaining guesses: 8
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _as__n_n_e
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 't' is not in the word. Remaining guesses: 5
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Oops! The letter 'p' is not in the word. Remaining guesses: 3
# Good guess! The word is now: _as__n_nge
# Good guess! The word is now: mas__n_nge
# Good guess! The word is now: mask_n_nge
# Good guess! The word is now: maskin_nge
# Good guess! The word is now: maskinonge
# Congratulations! The machine guessed the word: maskinonge
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _____a_
# Good guess! The word is now: _u___a_
# Good guess! The word is now: mu___a_
# Oops! The letter 'l' is not in the word. Remaining guesses: 8
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Good guess! The word is now: muc__a_
# Oops! The letter 'k' is not in the word. Remaining guesses: 6
# Oops! The letter 'n' is not in the word. Remaining guesses: 5
# Good guess! The word is now: muco_a_
# Good guess! The word is now: mucosas
# Congratulations! The machine guessed the word: mucosas
# Good guess! The word is now: _e________e___
# Good guess! The word is now: _e________e__a
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'x' is not in the word. Remaining guesses: 8
# Oops! The letter 'p' is not in the word. Remaining guesses: 7
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _e______i_e_ia
# Oops! The letter 'c' is not in the word. Remaining guesses: 5
# Good guess! The word is now: he______i_e_ia
# Oops! The letter 's' is not in the word. Remaining guesses: 4
# Good guess! The word is now: hem_____i_emia
# Good guess! The word is now: hemo__o_i_emia
# Good guess! The word is now: hemog_o_i_emia
# Good guess! The word is now: hemoglo_i_emia
# Good guess! The word is now: hemoglobi_emia
# Good guess! The word is now: hemoglobinemia
# Congratulations! The machine guessed the word: hemoglobinemia
# Good guess! The word is now: ________e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _____u__e_
# Oops! The letter 'n' is not in the word. Remaining guesses: 8
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _____ut_e_
# Good guess! The word is now: ____out_e_
# Oops! The letter 'c' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ____outhe_
# Good guess! The word is now: ___mouthe_
# Good guess! The word is now: ___mouthed
# Good guess! The word is now: __gmouthed
# Good guess! The word is now: b_gmouthed
# Good guess! The word is now: bigmouthed
# Congratulations! The machine guessed the word: bigmouthed
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____a____
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ____a__l_
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Oops! The letter 'g' is not in the word. Remaining guesses: 6
# Good guess! The word is now: __s_a__l_
# Oops! The letter 'v' is not in the word. Remaining guesses: 5
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Oops! The letter 'o' is not in the word. Remaining guesses: 3
# Oops! The letter 'n' is not in the word. Remaining guesses: 2
# Oops! The letter 'p' is not in the word. Remaining guesses: 1
# Good guess! The word is now: _is_a_ili
# Good guess! The word is now: kis_a_ili
# Good guess! The word is now: kiswa_ili
# Good guess! The word is now: kiswahili
# Congratulations! The machine guessed the word: kiswahili
# Good guess! The word is now: __e__e_____
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Good guess! The word is now: __er_err___
# Oops! The letter 't' is not in the word. Remaining guesses: 6
# Oops! The letter 'n' is not in the word. Remaining guesses: 5
# Oops! The letter 's' is not in the word. Remaining guesses: 4
# Oops! The letter 'f' is not in the word. Remaining guesses: 3
# Good guess! The word is now: o_er_err___
# Good guess! The word is now: over_err___
# Good guess! The word is now: overmerr___
# Good guess! The word is now: overmerri__
# Good guess! The word is now: overmerril_
# Good guess! The word is now: overmerrily
# Congratulations! The machine guessed the word: overmerrily
# Good guess! The word is now: __e
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'w' is not in the word. Remaining guesses: 7
# Oops! The letter 'm' is not in the word. Remaining guesses: 6
# Oops! The letter 'z' is not in the word. Remaining guesses: 5
# Oops! The letter 'f' is not in the word. Remaining guesses: 4
# Oops! The letter 'k' is not in the word. Remaining guesses: 3
# Good guess! The word is now: _re
# Oops! The letter 'p' is not in the word. Remaining guesses: 2
# Oops! The letter 'b' is not in the word. Remaining guesses: 1
# Good guess! The word is now: hre
# Congratulations! The machine guessed the word: hre
# Good guess! The word is now: __e___
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'p' is not in the word. Remaining guesses: 7
# Oops! The letter 'd' is not in the word. Remaining guesses: 6
# Oops! The letter 'j' is not in the word. Remaining guesses: 5
# Oops! The letter 't' is not in the word. Remaining guesses: 4
# Oops! The letter 'h' is not in the word. Remaining guesses: 3
# Oops! The letter 's' is not in the word. Remaining guesses: 2
# Oops! The letter 'r' is not in the word. Remaining guesses: 1
# Oops! The letter 'f' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: icebox
# Good guess! The word is now: _____e_e__e_
# Good guess! The word is now: _____e_ea_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'g' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ___n_e_ea_e_
# Oops! The letter 'f' is not in the word. Remaining guesses: 7
# Oops! The letter 'b' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Good guess! The word is now: ___n_e_ea_ed
# Good guess! The word is now: ___n_epea_ed
# Good guess! The word is now: s__n_epea_ed
# Good guess! The word is now: soon_epea_ed
# Good guess! The word is now: soonrepea_ed
# Good guess! The word is now: soonrepeated
# Congratulations! The machine guessed the word: soonrepeated
# Good guess! The word is now: ____e______e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____e_u____e_
# Good guess! The word is now: ___re_u____e_
# Oops! The letter 'q' is not in the word. Remaining guesses: 8
# Good guess! The word is now: i__re_u_i_ie_
# Oops! The letter 'f' is not in the word. Remaining guesses: 7
# Good guess! The word is now: i__re_u_i_ies
# Good guess! The word is now: in_re_u_i_ies
# Good guess! The word is now: incre_u_i_ies
# Good guess! The word is now: incredu_i_ies
# Good guess! The word is now: increduli_ies
# Good guess! The word is now: incredulities
# Congratulations! The machine guessed the word: incredulities
# Good guess! The word is now: ______e______
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'v' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _____re______
# Oops! The letter 'q' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _i__ire__i___
# Oops! The letter 'f' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _is_ire__i__s
# Good guess! The word is now: _is_ire_ti__s
# Good guess! The word is now: mis_ire_ti__s
# Good guess! The word is now: misdire_ti__s
# Good guess! The word is now: misdirecti__s
# Good guess! The word is now: misdirectio_s
# Good guess! The word is now: misdirections
# Congratulations! The machine guessed the word: misdirections
# Good guess! The word is now: ___e__e__e__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _u_e__e__e__
# Oops! The letter 'g' is not in the word. Remaining guesses: 8
# Oops! The letter 'n' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _u_e__e_fe__
# Oops! The letter 'b' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _upe_pe_fe__
# Good guess! The word is now: supe_pe_fe__
# Good guess! The word is now: superperfe__
# Good guess! The word is now: superperfec_
# Good guess! The word is now: superperfect
# Congratulations! The machine guessed the word: superperfect
# Good guess! The word is now: _______e___
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _u_____e___
# Oops! The letter 'b' is not in the word. Remaining guesses: 8
# Oops! The letter 'o' is not in the word. Remaining guesses: 7
# Oops! The letter 'q' is not in the word. Remaining guesses: 6
# Oops! The letter 't' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _u__i_ie___
# Oops! The letter 'v' is not in the word. Remaining guesses: 4
# Oops! The letter 'r' is not in the word. Remaining guesses: 3
# Oops! The letter 'g' is not in the word. Remaining guesses: 2
# Good guess! The word is now: _u__i_ien__
# Oops! The letter 'd' is not in the word. Remaining guesses: 1
# Good guess! The word is now: _uffi_ien__
# Good guess! The word is now: suffi_ien__
# Good guess! The word is now: sufficienc_
# Good guess! The word is now: sufficiency
# Congratulations! The machine guessed the word: sufficiency
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _a________
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Oops! The letter 'l' is not in the word. Remaining guesses: 6
# Oops! The letter 'm' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _a__r_____
# Oops! The letter 'w' is not in the word. Remaining guesses: 4
# Oops! The letter 'd' is not in the word. Remaining guesses: 3
# Oops! The letter 'p' is not in the word. Remaining guesses: 2
# Good guess! The word is now: _a__r___n_
# Good guess! The word is now: _at_r___n_
# Oops! The letter 'o' is not in the word. Remaining guesses: 1
# Good guess! The word is now: sat_r___n_
# Good guess! The word is now: satiri_in_
# Good guess! The word is now: satirizin_
# Good guess! The word is now: satirizing
# Congratulations! The machine guessed the word: satirizing
# Good guess! The word is now: ______e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: ___d__ed
# Good guess! The word is now: o__d__ed
# Oops! The letter 'r' is not in the word. Remaining guesses: 7
# Oops! The letter 't' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Oops! The letter 'n' is not in the word. Remaining guesses: 4
# Good guess! The word is now: o_idi_ed
# Good guess! The word is now: oxidi_ed
# Good guess! The word is now: oxidised
# Congratulations! The machine guessed the word: oxidised
# Good guess! The word is now: _e____e___e
# Good guess! The word is now: _e____e_a_e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _e____e_ate
# Oops! The letter 'l' is not in the word. Remaining guesses: 8
# Oops! The letter 'm' is not in the word. Remaining guesses: 7
# Good guess! The word is now: re____e_ate
# Oops! The letter 'i' is not in the word. Remaining guesses: 6
# Good guess! The word is now: re____enate
# Good guess! The word is now: reo___enate
# Good guess! The word is now: reox__enate
# Good guess! The word is now: reoxy_enate
# Good guess! The word is now: reoxygenate
# Congratulations! The machine guessed the word: reoxygenate
# Good guess! The word is now: _______e_________
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ___u___e_________
# Oops! The letter 'q' is not in the word. Remaining guesses: 8
# Good guess! The word is now: i__u___e__i_i_i__
# Good guess! The word is now: in_u___e__i_i_i__
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Oops! The letter 'o' is not in the word. Remaining guesses: 6
# Oops! The letter 'm' is not in the word. Remaining guesses: 5
# Good guess! The word is now: in_upp_e__i_i_i__
# Good guess! The word is now: insupp_essi_i_i__
# Good guess! The word is now: insuppressi_i_i__
# Good guess! The word is now: insuppressibi_i__
# Good guess! The word is now: insuppressibili__
# Good guess! The word is now: insuppressibilit_
# Good guess! The word is now: insuppressibility
# Congratulations! The machine guessed the word: insuppressibility
# Good guess! The word is now: ____e_____e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ____en____e_
# Good guess! The word is now: ____en__t_e_
# Good guess! The word is now: ____en_itie_
# Good guess! The word is now: ____ensities
# Good guess! The word is now: p__pensities
# Good guess! The word is now: pr_pensities
# Good guess! The word is now: propensities
# Congratulations! The machine guessed the word: propensities
# Good guess! The word is now: _____e__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'd' is not in the word. Remaining guesses: 7
# Good guess! The word is now: ___ffe__
# Oops! The letter 'n' is not in the word. Remaining guesses: 6
# Good guess! The word is now: t__ffe__
# Oops! The letter 'b' is not in the word. Remaining guesses: 5
# Oops! The letter 'l' is not in the word. Remaining guesses: 4
# Good guess! The word is now: tr_ffer_
# Good guess! The word is now: troffer_
# Good guess! The word is now: troffers
# Congratulations! The machine guessed the word: troffers
# Good guess! The word is now: e_______
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'd' is not in the word. Remaining guesses: 7
# Oops! The letter 'f' is not in the word. Remaining guesses: 6
# Oops! The letter 'r' is not in the word. Remaining guesses: 5
# Oops! The letter 'z' is not in the word. Remaining guesses: 4
# Oops! The letter 't' is not in the word. Remaining guesses: 3
# Good guess! The word is now: eb______
# Good guess! The word is now: eb____s_
# Good guess! The word is now: ebi__is_
# Good guess! The word is now: ebio_is_
# Good guess! The word is now: ebionis_
# ...
# Good guess! The word is now: __e__egea_e_
# Good guess! The word is now: t_e__egea_e_
# Good guess! The word is now: tre__egeare_
# Good guess! The word is now: treb_egeare_
# Good guess! The word is now: treblegeare_
# Good guess! The word is now: treblegeared
# Congratulations! The machine guessed the word: treblegeared
# Good guess! The word is now: _e___________
# Good guess! The word is now: _e____a______
# Good guess! The word is now: _e____a____u_
# Oops! The letter 'r' is not in the word. Remaining guesses: 9
# Oops! The letter 'c' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _e____a___mu_
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Oops! The letter 't' is not in the word. Remaining guesses: 6
# Good guess! The word is now: _es___a__smus
# Good guess! The word is now: oeso__a__smus
# Good guess! The word is now: oesop_a__smus
# Good guess! The word is now: oesopha__smus
# Good guess! The word is now: oesophag_smus
# Good guess! The word is now: oesophagismus
# Congratulations! The machine guessed the word: oesophagismus
# Good guess! The word is now: _____________e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _u________u__e_
# Good guess! The word is now: qu________u__e_
# Good guess! The word is now: qui_______u__e_
# Good guess! The word is now: qui_______un_e_
# Good guess! The word is now: qui_____p_un_e_
# Good guess! The word is now: quic_c__p_un_e_
# Oops! The letter 't' is not in the word. Remaining guesses: 8
# Good guess! The word is now: quickc__p_un_e_
# Good guess! The word is now: quickco_poun_e_
# Good guess! The word is now: quickcompoun_e_
# Good guess! The word is now: quickcompounded
# Congratulations! The machine guessed the word: quickcompounded
# Good guess! The word is now: _ee__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'w' is not in the word. Remaining guesses: 7
# Oops! The letter 'z' is not in the word. Remaining guesses: 6
# Oops! The letter 'm' is not in the word. Remaining guesses: 5
# Oops! The letter 'r' is not in the word. Remaining guesses: 4
# Oops! The letter 's' is not in the word. Remaining guesses: 3
# Oops! The letter 'g' is not in the word. Remaining guesses: 2
# Oops! The letter 'n' is not in the word. Remaining guesses: 1
# Oops! The letter 'p' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: leech
# Good guess! The word is now: e_e___e__
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: e_e___ess
# Oops! The letter 'f' is not in the word. Remaining guesses: 7
# Oops! The letter 'y' is not in the word. Remaining guesses: 6
# Good guess! The word is now: e_en__ess
# Oops! The letter 'o' is not in the word. Remaining guesses: 5
# Oops! The letter 'b' is not in the word. Remaining guesses: 4
# Oops! The letter 'c' is not in the word. Remaining guesses: 3
# Good guess! The word is now: even__ess
# Good guess! The word is now: event_ess
# Good guess! The word is now: eventless
# Congratulations! The machine guessed the word: eventless
# Good guess! The word is now: __________e
# Good guess! The word is now: _______a__e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: __s__ssa__e
# Oops! The letter 'f' is not in the word. Remaining guesses: 8
# Oops! The letter 'r' is not in the word. Remaining guesses: 7
# Oops! The letter 'y' is not in the word. Remaining guesses: 6
# Oops! The letter 'c' is not in the word. Remaining guesses: 5
# Oops! The letter 'o' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _is_issa__e
# Good guess! The word is now: _ismissa__e
# Good guess! The word is now: dismissa__e
# Good guess! The word is now: dismissab_e
# Good guess! The word is now: dismissable
# Congratulations! The machine guessed the word: dismissable
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: __a__a
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'k' is not in the word. Remaining guesses: 7
# Oops! The letter 'w' is not in the word. Remaining guesses: 6
# Oops! The letter 'c' is not in the word. Remaining guesses: 5
# Good guess! The word is now: __a_na
# Oops! The letter 'b' is not in the word. Remaining guesses: 4
# Oops! The letter 'l' is not in the word. Remaining guesses: 3
# Oops! The letter 'm' is not in the word. Remaining guesses: 2
# Oops! The letter 'p' is not in the word. Remaining guesses: 1
# Good guess! The word is now: __arna
# Good guess! The word is now: d_arna
# Good guess! The word is now: dharna
# Congratulations! The machine guessed the word: dharna
# Good guess! The word is now: _e____
# Good guess! The word is now: _e_a_a
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'c' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _era_a
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Oops! The letter 'k' is not in the word. Remaining guesses: 6
# Oops! The letter 'g' is not in the word. Remaining guesses: 5
# Oops! The letter 'p' is not in the word. Remaining guesses: 4
# Good guess! The word is now: yera_a
# Good guess! The word is now: yerava
# Congratulations! The machine guessed the word: yerava
# Good guess! The word is now: _e_____e
# Good guess! The word is now: _ea____e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: seas___e
# Good guess! The word is now: seash__e
# Good guess! The word is now: seashi_e
# Good guess! The word is now: seashine
# Congratulations! The machine guessed the word: seashine
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ___a_____
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: __la_____
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Oops! The letter 'b' is not in the word. Remaining guesses: 6
# Good guess! The word is now: r_la_____
# Oops! The letter 'h' is not in the word. Remaining guesses: 5
# Oops! The letter 'i' is not in the word. Remaining guesses: 4
# Oops! The letter 't' is not in the word. Remaining guesses: 3
# Oops! The letter 'm' is not in the word. Remaining guesses: 2
# Good guess! The word is now: r_la_d___
# Oops! The letter 'y' is not in the word. Remaining guesses: 1
# Good guess! The word is now: r_la_ds__
# Oops! The letter 'f' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: rolandson
# Good guess! The word is now: __e_e_e__e_
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Oops! The letter 'r' is not in the word. Remaining guesses: 6
# Oops! The letter 'n' is not in the word. Remaining guesses: 5
# Oops! The letter 'k' is not in the word. Remaining guesses: 4
# Oops! The letter 'p' is not in the word. Remaining guesses: 3
# Good guess! The word is now: __e_e_e_te_
# Oops! The letter 'l' is not in the word. Remaining guesses: 2
# Oops! The letter 'm' is not in the word. Remaining guesses: 1
# Good guess! The word is now: __ede_e_ted
# Good guess! The word is now: w_ede_e_ted
# Good guess! The word is now: woede_e_ted
# Good guess! The word is now: woedeje_ted
# Good guess! The word is now: woedejected
# Congratulations! The machine guessed the word: woedejected
# Good guess! The word is now: ____e__e_e________
# Good guess! The word is now: ____e__e_e__a_____
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: __s_e__ese__a____s
# Good guess! The word is now: __s_ep_ese__a____s
# Good guess! The word is now: __sreprese__a____s
# Good guess! The word is now: m_sreprese__a____s
# Good guess! The word is now: misreprese__a_i__s
# Good guess! The word is now: misrepresen_a_i_ns
# Good guess! The word is now: misrepresentati_ns
# Good guess! The word is now: misrepresentations
# Congratulations! The machine guessed the word: misrepresentations
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____a___
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'r' is not in the word. Remaining guesses: 7
# Oops! The letter 'p' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ____a_i_
# Oops! The letter 'm' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _l__a_i_
# Good guess! The word is now: _lo_a_i_
# Oops! The letter 'd' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _lo_ati_
# Oops! The letter 'b' is not in the word. Remaining guesses: 3
# Oops! The letter 'n' is not in the word. Remaining guesses: 2
# Good guess! The word is now: flo_ati_
# Good guess! The word is now: flokati_
# Good guess! The word is now: flokatis
# Congratulations! The machine guessed the word: flokatis
# Good guess! The word is now: __e________e_
# Good guess! The word is now: __ea_____a_e_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: __ea__h__a_e_
# Good guess! The word is now: __ear_hr_a_e_
# Good guess! The word is now: c_ear_hr_a_e_
# Good guess! The word is now: clear_hr_a_e_
# Good guess! The word is now: clearthr_ate_
# Good guess! The word is now: clearthroate_
# Good guess! The word is now: clearthroated
# Congratulations! The machine guessed the word: clearthroated
# Good guess! The word is now: __ee_____
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'c' is not in the word. Remaining guesses: 7
# Oops! The letter 'o' is not in the word. Remaining guesses: 6
# Oops! The letter 'l' is not in the word. Remaining guesses: 5
# Oops! The letter 'm' is not in the word. Remaining guesses: 4
# Oops! The letter 'b' is not in the word. Remaining guesses: 3
# Good guess! The word is now: __ee___s_
# Oops! The letter 'k' is not in the word. Remaining guesses: 2
# Oops! The letter 'p' is not in the word. Remaining guesses: 1
# Good guess! The word is now: _ree___s_
# Oops! The letter 'x' is not in the word. Remaining guesses: 0
# Sorry, the machine ran out of guesses. The word was: greenfish
# Good guess! The word is now: _e___________e
# Good guess! The word is now: _e__a________e
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'x' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _ep_a________e
# Good guess! The word is now: _ep_ar_______e
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Oops! The letter 's' is not in the word. Remaining guesses: 6
# Oops! The letter 'k' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _ep_ar______te
# Oops! The letter 'w' is not in the word. Remaining guesses: 4
# Good guess! The word is now: _ep_ar__i__ite
# Oops! The letter 'd' is not in the word. Remaining guesses: 3
# Good guess! The word is now: _ephar__i_hite
# Good guess! The word is now: zephar__i_hite
# Good guess! The word is now: zepharo_i_hite
# Good guess! The word is now: zepharovi_hite
# Good guess! The word is now: zepharovichite
# Congratulations! The machine guessed the word: zepharovichite
# Good guess! The word is now: _e__e_______
# Good guess! The word is now: _e__e____a__
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'g' is not in the word. Remaining guesses: 8
# Good guess! The word is now: _en_e____a__
# Good guess! The word is now: _en_e__r_ar_
# Good guess! The word is now: _en_e__r_ard
# Oops! The letter 'm' is not in the word. Remaining guesses: 7
# Oops! The letter 't' is not in the word. Remaining guesses: 6
# Good guess! The word is now: hen_e__r_ard
# Good guess! The word is now: hence__r_ard
# Good guess! The word is now: hencef_r_ard
# Good guess! The word is now: hencefor_ard
# Good guess! The word is now: henceforward
# Congratulations! The machine guessed the word: henceforward
# Good guess! The word is now: _______e__e
# Good guess! The word is now: ___a___e__e
# Good guess! The word is now: ___au__e__e
# Oops! The letter 's' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ___au__e_ce
# Oops! The letter 'l' is not in the word. Remaining guesses: 8
# Oops! The letter 'm' is not in the word. Remaining guesses: 7
# Good guess! The word is now: _r_au__e_ce
# Good guess! The word is now: _r_au__ence
# Oops! The letter 't' is not in the word. Remaining guesses: 6
# Oops! The letter 'g' is not in the word. Remaining guesses: 5
# Good guess! The word is now: _r_au_ience
# Good guess! The word is now: pr_au_ience
# Good guess! The word is now: proau_ience
# Good guess! The word is now: proaudience
# Congratulations! The machine guessed the word: proaudience
# Good guess! The word is now: _____e_____
# Good guess! The word is now: a____e___a_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Oops! The letter 'p' is not in the word. Remaining guesses: 8
# Good guess! The word is now: a____e___al
# Oops! The letter 's' is not in the word. Remaining guesses: 7
# Good guess! The word is now: a____en__al
# Good guess! The word is now: a____ent_al
# Oops! The letter 'g' is not in the word. Remaining guesses: 6
# Oops! The letter 'y' is not in the word. Remaining guesses: 5
# Good guess! The word is now: a__i_ential
# Good guess! The word is now: a__idential
# Good guess! The word is now: accidential
# Congratulations! The machine guessed the word: accidential
# Good guess! The word is now: e_____________
# Oops! The letter 'a' is not in the word. Remaining guesses: 9
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Good guess! The word is now: e____s________
# Oops! The letter 'g' is not in the word. Remaining guesses: 7
# Good guess! The word is now: e____s____r___
# Good guess! The word is now: e____si___r___
# Good guess! The word is now: e__l_si___r___
# Oops! The letter 'v' is not in the word. Remaining guesses: 6
# Good guess! The word is now: e__l_si_n_r___
# Good guess! The word is now: e__losion_roo_
# Good guess! The word is now: ex_losion_roo_
# Good guess! The word is now: explosionproo_
# Good guess! The word is now: explosionproof
# Congratulations! The machine guessed the word: explosionproof
# Good guess! The word is now: _______e__
# Good guess! The word is now: _______ea_
# Oops! The letter 'u' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _____t_ea_
# Good guess! The word is now: ____hthea_
# Good guess! The word is now: f___hthea_
# Good guess! The word is now: fl__hthea_
# Good guess! The word is now: fli_hthea_
# Good guess! The word is now: flighthea_
# Good guess! The word is now: flighthead
# Congratulations! The machine guessed the word: flighthead
# Good guess! The word is now: _____e_____e
# Good guess! The word is now: _____e__a__e
# Good guess! The word is now: ____ue__a__e
# Oops! The letter 'r' is not in the word. Remaining guesses: 9
# Good guess! The word is now: ____ue__ab_e
# Oops! The letter 'q' is not in the word. Remaining guesses: 8
# Oops! The letter 't' is not in the word. Remaining guesses: 7
# Oops! The letter 'h' is not in the word. Remaining guesses: 6
# Good guess! The word is now: ___lue__able
# Good guess! The word is now: i__lue__able
# Good guess! The word is now: in_luen_able
# Good guess! The word is now: influen_able
# Good guess! The word is now: influencable
# Congratulations! The machine guessed the word: influencable
# Oops! The letter 'e' is not in the word. Remaining guesses: 9
# Good guess! The word is now: _____a__a
# Oops! The letter 'u' is not in the word. Remaining guesses: 8
# Oops! The letter 'l' is not in the word. Remaining guesses: 7
# Oops! The letter 'b' is not in the word. Remaining guesses: 6
# Oops! The letter 'm' is not in the word. Remaining guesses: 5
# Good guess! The word is now: __i__a_ia
# Good guess! The word is now: __ip_a_ia
# Good guess! The word is now: _rip_a_ia
# Good guess! The word is now: trip_a_ia
# Good guess! The word is now: tripha_ia
# Good guess! The word is now: triphasia
# Congratulations! The machine guessed the word: triphasia
# Accuracy: 0.91
